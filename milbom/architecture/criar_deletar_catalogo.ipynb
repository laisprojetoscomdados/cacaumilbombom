# %% [markdown]
# #Create

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS milbom_bronze;
CREATE SCHEMA IF NOT EXISTS milbom_silver;
CREATE SCHEMA IF NOT EXISTS milbom_gold;

# %% [markdown]
# #DELETE

# %%
# %sql
DROP TABLE IF EXISTS milbom_bronze.bakehouse_sales_franchises;
DROP TABLE IF EXISTS milbom_bronze.bakehouse_sales_customers;
DROP TABLE IF EXISTS milbom_bronze.bakehouse_sales_transactions;
DROP SCHEMA IF EXISTS milbom_bronze;

# %%
# %sql
DROP TABLE IF EXISTS milbom_silver.bakehouse_customers;
DROP TABLE IF EXISTS milbom_silver.bakehouse_store;
DROP TABLE IF EXISTS milbom_silver.bakehouse_sales_transactions;
DROP TABLE IF EXISTS milbom_silver.bakehouse_transactions_enrich;
DROP SCHEMA IF EXISTS milbom_silver;

# %%
# %sql
DROP TABLE IF EXISTS milbom_gold.kpi_revenue_period;
DROP TABLE IF EXISTS milbom_gold.kpi_sales_product_category;
DROP TABLE IF EXISTS milbom_gold.kpi_store_performance;
DROP TABLE IF EXISTS milbom_gold.kpi_ticket_customer;
DROP SCHEMA IF EXISTS milbom_gold;
